# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 10, 10000)
x = np.log(1 + t) * np.cos(t * 2 * np.pi) 
y = np.log(1 + t) * np.sin(t * 2 * np.pi) 

plt.plot(x, y)
plt.show()
