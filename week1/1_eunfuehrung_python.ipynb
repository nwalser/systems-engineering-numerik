# %%
# exercise 1
import numpy as np
import matplotlib.pyplot as plt

sigmas = np.array([1/4, 1/3, 1/2])
x = np.linspace(-2, 2, 10000)
fig, axs = plt.subplots(len(sigmas))

for idx, sigma in enumerate(sigmas):
    y = np.exp(1) ** - ((x**2) / sigma)
    axs[idx].plot(x, y)

    axs[idx].set_xlabel("X")
    axs[idx].set_ylabel(f"Y ({sigma:.2f})")

# %%
# exercise 2
def geometric_series(k, n = 10):
    pass
    # didn't understand the formula

# %%
# exercise 3
epsilon = 10e-7

f = lambda k: (1+1/(2**k))**(2**k)
c = lambda c: abs(c - np.exp(1)) < epsilon

x = np.linspace(0, 10e2, 10000)
y = np.vectorize(f, otypes=[object])(x)
c = np.vectorize(c, otypes=[object])(y)

plt.xscale('log')
plt.plot(x, y)
plt.plot(x, c)
plt.show()

# verfahren wird ca bei k=500 instabil aufgrund der rundungsfehler
