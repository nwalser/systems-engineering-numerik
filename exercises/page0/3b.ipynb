# %%
import numpy as np
import matplotlib . pyplot as plt

def f(x):
    if x < 0:
        return 1
    if x >= 1:
        return 0
    return 1-x

x = np.linspace (-2 , 2, 400)
y = np.vectorize(f, otypes=[np.floating])(x)

plt.plot(x, y)
plt.show()
